# %%
# !pip install webdriver-manager
# Out:
# Collecting webdriver-manager
#   Downloading webdriver_manager-3.5.4-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: requests in c:\users\akash.g\anaconda3\lib\site-packages (from webdriver-manager) (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akash.g\anaconda3\lib\site-packages (from requests->webdriver-manager) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\akash.g\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\akash.g\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akash.g\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.2)
# Installing collected packages: webdriver-manager
# Successfully installed webdriver-manager-3.5.4

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %%
class Web_Scraping():
    def scraping(self):
        Status = []
        Planholders = [] 
        Due_Date = []
        ID = []
        Agency_Name = []
        Titles = []
        Broadcast_Date = []
        driver = webdriver.Chrome(ChromeDriverManager().install())
        url = "https://www.demandstar.com/app/agencies/california/city-of-sunnyvale/procurement-opportunities/e9a860f4-8f17-43af-aae7-e5dc8389f36e/"
        driver.get(url)
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        spans = soup.select('.text-truncate span')
        spans1 = soup.select('.list-inline-item:nth-child(4)')
        spans2 = soup.select('.list-inline-item:nth-child(2)')
        spans3 = soup.select('.list-inline-item:nth-child(1)')
        spans4 = soup.select('p')
        spans5 = soup.select('.mw-75')
        spans6 = soup.select('.list-inline-item:nth-child(3)')
        for span in spans:
            Status.append(span.text.strip())
        for span in spans1:
            Planholders.append(span.text.replace("#Planholders:","").strip())
        for span in spans2:
            Due_Date.append(span.text.replace("Due:","").strip())
        for span in spans3:
            ID.append(span.text.replace("Due:","").strip())
        for span in spans4:
            Agency_Name.append(span.text.strip())
            Agency_Name = Agency_Name[0:100]
        for span in spans5:
            Titles.append(span.text.strip())
        spans6 = soup.select('.list-inline-item:nth-child(3)')
        for span in spans6:
            Broadcast_Date.append(span.text.replace("Broadcast:","").strip())
        df=pd.DataFrame({'Titles':Titles,
                 'Agency_Name':Agency_Name,
                 'ID':ID,
                 'Planholders':Planholders,
                 'Broadcast_Date':Broadcast_Date,
                 'Due_Date':Due_Date,
                 'Status':Status,
                })
        df.to_csv('data.csv', index=False, encoding='utf-8')
        print(df.head(20))    
        return "scrapping successful"



if __name__ == "__main__":
    process = Web_Scraping()
    process.scraping()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [C:\Users\Akash.G\.wdm\drivers\chromedriver\win32\99.0.4844.51\chromedriver.exe] found in cache
# C:\Users\Akash.G\AppData\Local\Temp/ipykernel_43048/378711638.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
#                                                Titles  \
# 0               Polymer, Coagulant/Floculant Products
# 1                         Network Appliance Equipment
# 2   Concrete Sidewalk, Curb, Gutter and Driveway A...
# 3   Professional Services for Safety and Loss Control
# 4   Workforce Innovation & Opportunity Act Adult &...
# 5   Workforce Innovation & Opportunity Act Youth S...
# 6   Department of Public Safety Emergency Generato...
# 7   Trenchless Sewer Line Pipe Bursting, Repair an...
# 8   On-Call Contracts for Engineering Support Serv...
# 9   Professional Services Assistance for a Nonresi...
# 10   Lakewood Park Renovation and Enhancement Project
# 11   Provide Pre-Employment Background Investigations
# 12    Utility Users Tax Audit and Consulting Services
# 13  Professional Engineering Services for Traffic ...
# 14  Provide, Remove and Install Vehicle and Pedest...
# 10          50     01/14/2022  02/23/2022  Under Evaluation
# 11          14     01/21/2022  02/16/2022  Under Evaluation
# 12          10     01/14/2022  02/04/2022  Under Evaluation
# 13          28     12/07/2021  01/26/2022  Under Evaluation
# 14          16     12/22/2021  01/21/2022  Under Evaluation
# 15          17     12/22/2021  01/19/2022  Under Evaluation
# 16          43     11/18/2021  01/07/2022  Under Evaluation
# 17          17     11/29/2021  12/15/2021  Under Evaluation
# 18          58     10/28/2021  12/14/2021  Under Evaluation
# 19          42     11/05/2021  12/08/2021  Under Evaluation

# %%
pd.read_csv('data.csv')
# Out:
#                                                Titles  \
# 0               Polymer, Coagulant/Floculant Products
# 1                         Network Appliance Equipment
# 2   Concrete Sidewalk, Curb, Gutter and Driveway A...
# 3   Professional Services for Safety and Loss Control
# 4   Workforce Innovation & Opportunity Act Adult &...
# ..                                                ...
# 95                            Annual Slurry Seal 2020
# 96  On-Call Fire Protection & Building Safety Revi...
# 97           Comprehensive Development User Fee Study
# 98  Concrete Sidewalk, Curb, Gutter, Driveway Repl...
# 99  Caribbean Drive Parking and Trail Access Enhan...
#
#                          Agency_Name                            ID  \
# 0   City of Sunnyvale, Sunnyvale, CA    ID: RFQL-F22-095-0-2022/LV
# 1   City of Sunnyvale, Sunnyvale, CA    ID: IFB-F22-089-0-2022/MAP
# 2   City of Sunnyvale, Sunnyvale, CA     ID: IFB-PW22-07-0-2022/LV
# 3   City of Sunnyvale, Sunnyvale, CA     ID: RFP-F22-064-0-2022/LV
# 4   City of Sunnyvale, Sunnyvale, CA  ID: RFP-NOVA-22-01-0-2022/lj
# ..                               ...                           ...
# 95  City of Sunnyvale, Sunnyvale, CA     ID: IFB-PW20-13-0-2020/LV
# 96  City of Sunnyvale, Sunnyvale, CA    ID: RFP-F19-235-0-2020/JLe
# 97  City of Sunnyvale, Sunnyvale, CA    ID: RFP-F20-066-0-2020/JLe
# 98  City of Sunnyvale, Sunnyvale, CA    ID: IFB-PW20-07-0-2020/JLe
# 99  City of Sunnyvale, Sunnyvale, CA     ID: IFB-PW20-06-0-2020/LV
#
#     Planholders Broadcast_Date    Due_Date   Status
# 0            15     03/23/2022  06/16/2022   Active
# 1             5     03/28/2022  04/13/2022   Active
# 2            11     03/25/2022  04/13/2022   Active
# 3            10     03/02/2022  04/05/2022   Active
# 4             3     03/01/2022  04/04/2022   Active
# ..          ...            ...         ...      ...
# 95           19     01/02/2020  01/29/2020  Awarded
# 96           22     12/05/2019  01/10/2020  Awarded
# 97           11     11/15/2019  12/13/2019  Awarded
# 98           20     11/21/2019  12/11/2019  Awarded
# 99           25     11/07/2019  12/04/2019  Awarded
#
# [100 rows x 7 columns]
